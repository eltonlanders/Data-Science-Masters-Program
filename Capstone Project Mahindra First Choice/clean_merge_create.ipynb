# %%
import numpy as np        
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('float_format', '{:f}'.format)

# %%
customer_df = pd.read_excel('data/Customer_Data.xlsx')

# %%
customer_df.head()
# Out:
#   Business Partner Customer No.  Partner Type Data Origin  Title  \
# 0               31            1      1.000000        Z001    nan
# 1               32            2      1.000000        Z005    nan
# 2               34            4      1.000000        Z005    nan
# 3               35            5      1.000000        Z005    nan
# 4               42            7      1.000000        Z008    nan
#
#    Marital Status  Occupation Date of Birth Death date
# 0             nan         nan           NaN        NaT
# 1             nan         nan           NaN        NaT
# 2        2.000000         nan           NaN        NaT
# 3             nan         nan           NaN        NaT
# 4             nan         nan           NaN        NaT

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555338 entries, 0 to 555337
# Data columns (total 9 columns):
# Business Partner    555338 non-null object
# Customer No.        555338 non-null object
# Partner Type        555260 non-null float64
# Data Origin         555202 non-null object
# Title               509031 non-null float64
# Marital Status      16037 non-null float64
# Occupation          14558 non-null float64
# Date of Birth       13444 non-null object
# Death date          663 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 38.1+ MB

# %%
customer_df.isnull().sum()* 100 / len(customer_df)
# Out:
# Business Partner    0.000000
# Customer No.        0.000000
# Partner Type        0.014046
# Data Origin         0.024490
# Title               8.338525
# Marital Status     97.112209
# Occupation         97.378533
# Date of Birth      97.579132
# Death date         99.880613
# dtype: float64

# %%
customer_df.drop(columns=['Business Partner','Marital Status','Occupation','Date of Birth','Death date'],axis=1,inplace=True)

# %%
customer_df.shape
# Out:
# (555338, 4)

# %%
customer_df.dropna(inplace=True)

# %%
customer_df.isnull().sum()
# Out:
# Customer No.    0
# Partner Type    0
# Data Origin     0
# Title           0
# dtype: int64

# %%
customer_df['Customer No.'].nunique()
# Out:
# 509025

# %%
# map column description
def map_description(dataset,col, map_dict):
    dataset[col] = dataset[col].astype(str).map(map_dict)
    return dataset

#assumed - 'Z006':'Ref-Employee'

data_origin_dict = { 'Z001':'Camp-Outdoor','Z002':'Camp-Workshop','Z003':'Emailers',
                     'Z004':'Fleet','Z005':'Ref-Customer','Z006':'Ref-Employee',
                     'Z007':'Used Car Dealer','Z008':'Just Dial/Other',
                     'Z009':'Snapdeal/Web','Z010':'Company website',
                     'Z011':'Float activity','Z012':'Petrol pump',
                     'Z013':'Hoardings/ADVT','Z014':'Insurance Co',
                     'Z015':'Television AD','Z016':'Newspaper AD',
                     'Z017':'Newsppr leaflet','Z018':'Sales Activity',
                     'Z019':'Spotted outlet','Z020':'M & M Employee',
                     'Z021':'Outdoor Activty','Z022':'Radio'
                  }

#assumed - '9002.0':'Other'
partner_type_dict = {'1.0':'Retail','2.0':'Corporate','3.0':'Fleet',
                     '4.0':'Employee','9001.0':'Insurance Company',
                     '9002.0':'Other','9003.0':'Contact Person'
                    }

title_type_dict = {'1.0':'Female','2.0':'Male'}



custmer_df = map_description(customer_df,'Data Origin', data_origin_dict)
custmer_df = map_description(customer_df,'Partner Type', partner_type_dict)
custmer_df = map_description(customer_df,'Title', title_type_dict)

# %%
customer_df.head()
# Out:
#    Customer No. Partner Type      Data Origin Title
# 13           19       Retail   Hoardings/ADVT  Male
# 24           31       Retail     Ref-Customer  Male
# 28           35       Retail  Outdoor Activty  Male
# 30           38       Retail     Ref-Customer  Male
# 33           42       Retail     Ref-Customer  Male

# %%
customer_df.shape
# Out:
# (509025, 4)

# %%
plant_df = pd.read_excel('data/Plant Master.xlsx')

# %%
plant_df.head()
# Out:
#   Plant                          Name 1 Valuation Area Customer no. - plant  \
# 0  BC07                      NERKUNDRAM           BC07               PLBC07
# 1  BC30              SAS NAGAR - MOHALI           BC30               PLBC30
# 2  X001       X001 - AUTO PLANET WHEELS           X001               PLX001
# 3  X002  X002 - BHANDARI INDUSTRIES PVT           X002               PLX002
# 4  X003  X003 - Om Sri Satya Sai Automo           X003               PLX003
#
#   Vendor number plant Factory calendar     Name 2  \
# 0              PLBC07               IN        NaN
# 1              PLBC30               IN        NaN
# 2                 NaN               IN      Thane
# 3                 NaN               IN  Ghaziabad
# 4                 NaN               IN  Bengaluru
#
#           House number and street        PO Box  Postal Code       City  \
# 0   No.117 Poonamallee High Road, 600107.000000       600107    Chennai
# ...

# %%
plant_df.drop(columns=[ 'Valuation Area', 'Customer no. - plant', 'Vendor number plant', 'Factory calendar', 'Name 2' ,'PO Box'],inplace=True)

# %%
plant_df.head()
# Out:
#   Plant                          Name 1         House number and street  \
# 0  BC07                      NERKUNDRAM   No.117 Poonamallee High Road,
# 1  BC30              SAS NAGAR - MOHALI                C-118, Phase 07,
# 2  X001       X001 - AUTO PLANET WHEELS    Unit No.3, Kothari Compound,
# 3  X002  X002 - BHANDARI INDUSTRIES PVT       18/1, C Site 4, Sahibabad
# 4  X003  X003 - Om Sri Satya Sai Automo  #75, Sy.No. 83/2, Panathur Mai
#
#    Postal Code       City Sales organization          State
# 0       600107    Chennai               MFCS     Tamil Nadu
# 1       160055     Mohali               MFCS         Punjab
# 2       400610      Thane               MFCA    Maharashtra
# 3       201010  Ghaziabad               MFCA  Uttar Pradesh
# 4       560087  Bengaluru               MFCB      Karnataka

# %%
plant_df.isnull().sum()* 100 / len(plant_df)
# Out:
# Plant                     0.000000
# Name 1                    0.000000
# House number and street   0.456621
# Postal Code               0.000000
# City                      0.000000
# Sales organization        1.141553
# State                     0.000000
# dtype: float64

# %%
plant_df.dropna(inplace=True)

# %%
plant_df.isnull().sum()* 100 / len(plant_df)
# Out:
# Plant                     0.000000
# Name 1                    0.000000
# House number and street   0.000000
# Postal Code               0.000000
# City                      0.000000
# Sales organization        0.000000
# State                     0.000000
# dtype: float64

# %%
plant_df.shape
# Out:
# (431, 7)

# %%
plant_df['Plant'].nunique()
# Out:
# 431

# %%
plant_df.head()
# Out:
#   Plant                          Name 1         House number and street  \
# 0  BC07                      NERKUNDRAM   No.117 Poonamallee High Road,
# 1  BC30              SAS NAGAR - MOHALI                C-118, Phase 07,
# 2  X001       X001 - AUTO PLANET WHEELS    Unit No.3, Kothari Compound,
# 3  X002  X002 - BHANDARI INDUSTRIES PVT       18/1, C Site 4, Sahibabad
# 4  X003  X003 - Om Sri Satya Sai Automo  #75, Sy.No. 83/2, Panathur Mai
#
#    Postal Code       City Sales organization          State
# 0       600107    Chennai               MFCS     Tamil Nadu
# 1       160055     Mohali               MFCS         Punjab
# 2       400610      Thane               MFCA    Maharashtra
# 3       201010  Ghaziabad               MFCA  Uttar Pradesh
# 4       560087  Bengaluru               MFCB      Karnataka

# %%
plant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 431 entries, 0 to 437
# Data columns (total 7 columns):
# Plant                      431 non-null object
# Name 1                     431 non-null object
# House number and street    431 non-null object
# Postal Code                431 non-null int64
# City                       431 non-null object
# Sales organization         431 non-null object
# State                      431 non-null object
# dtypes: int64(1), object(6)
# memory usage: 26.9+ KB

# %%
jtd_df = pd.read_csv('data/JTD.csv')

# %%
jtd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5619484 entries, 0 to 5619483
# Data columns (total 10 columns):
# Unnamed: 0             int64
# DBM Order              int64
# Order Item             int64
# Material               object
# Labor Value Number     object
# Description            object
# Item Category          object
# Order Quantity         float64
# Target quantity UoM    object
# Net value              float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 428.7+ MB

# %%
jtd_df.shape
# Out:
# (5619484, 10)

# %%
jtd_df.head()
# Out:
#    Unnamed: 0  DBM Order  Order Item           Material Labor Value Number  \
# 0           0      22385         180        OSLCC_SRV31                NaN
# 1           1      23910          10    1DM279018170117                NaN
# 2           2      23910          40      1IS150203BE01                NaN
# 3           3      23910          60    1DM279001990173                NaN
# 4           4      23910          70  1DM88552790S001SA                NaN
#
#                                Description Item Category  Order Quantity  \
# 0  MACHINING RR.SUSPENSION CHARGE  (MAJOR)          P010        1.200000
# 1           ASSY.OIL COOLER (6-PLATE) (VOR          P002        1.000000
# 2           FRONT WHEEL BEARING/ LUBRICATE          P002        1.000000
# 3          ASSY.CYL.HEAD W /O INJ.(NA W /O          P002        1.000000
# 4           Engine Overhaul Kit -Indica Di          P002        1.000000
#
#   Target quantity UoM    Net value
# 0                 MIN  1869.870000
# ...

# %%
jtd_df.isnull().sum()* 100 / len(jtd_df)
# Out:
# Unnamed: 0             0.000000
# DBM Order              0.000000
# Order Item             0.000000
# Material               0.918750
# Labor Value Number    67.159778
# Description            0.918750
# Item Category          0.000000
# Order Quantity         0.000000
# Target quantity UoM    0.918750
# Net value              0.000000
# dtype: float64

# %%
jtd_df.drop(columns= ['Unnamed: 0','Labor Value Number'],axis=1,inplace=True)

# %%
jtd_df.dropna(inplace=True) # dropping null values

# %%
jtd_df.shape
# Out:
# (5567855, 8)

# %%
len(jtd_df['Order Quantity'].unique())
# Out:
# 3604

# %%
aggregation_jtd_dbno={ 'Description' : {'Description' : lambda x: str(set(x)).strip('{}').replace("'","")},
                      'Item Category' : {'Item Category' : lambda x: str(set(x)).strip('{}').replace("'","")}, 
                      'Order Quantity' : {'Order Quantity' : 'sum'},
                      'Net value' : {'Net value' : 'sum'} }
jtd_grouped = jtd_df.groupby('DBM Order')['Description','Item Category','Order Quantity','Net value'].agg(aggregation_jtd_dbno).reset_index()
# Out:
# C:\Users\purni\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)

# %%
jtd_grouped.head()
# Out:
#    DBM Order                                        Description  \
# 0          4  MACHINING CYLINDER HEAD  (PETROL), GLASS SEALA...
# 1          5  CLEAFUEL FILTER, REPLACE BRAKE PAD (BOTH SIDE)...
# 2          6  REPLACE STARTER MOTOR ASSY, Paid Service-Minor...
# 3          7                              MISC LABOR 0.25 HOURS
# 4          8  AIR FILTER, ELF Synthetic Engine OIL, WASHER 1...
#
#             Item Category  Order Quantity    Net value
# 0  P010, P011, P001, P002      731.600000 16998.490000
# 1              P001, P002      290.200000  3779.800000
# 2                    P001      109.000000  1340.370000
# 3                    P001       36.500000   167.360000
# 4              P001, P002       69.000000  2306.940000

# %%
jtd_grouped.shape
# Out:
# (936619, 5)

# %%
invoice_df = pd.read_csv('data/Final_invoice.csv',low_memory=False)

# %%
invoice_df.head()
# Out:
#    Unnamed: 0  Amt Rcvd From Custom  Amt Rcvd From Ins Co Area / Locality  \
# 0           0              0.000000              0.000000        MAJIWADA
# 1           1              0.000000              0.000000           THNAE
# 2           2              0.000000              0.000000           THANE
# 3           3              0.000000              0.000000           THNAE
# 4           4              0.000000              0.000000           THANE
#
#    CGST(14%)  CGST(2.5%)  CGST(6%)  CGST(9%)      CITY Cash /Cashless Type  \
# 0   0.000000    0.000000  0.000000  0.000000     Thane                 NaN
# 1   0.000000    0.000000  0.000000  0.000000     THNAE                 NaN
# 2   0.000000    0.000000  0.000000  0.000000  THANE[W]                 NaN
# 3   0.000000    0.000000  0.000000  0.000000     THNAE                 NaN
# 4   0.000000    0.000000  0.000000  0.000000     THANE                 NaN
#
# ...

# %%
invoice_df.isnull().sum()* 100 / len(invoice_df)
# Out:
# Unnamed: 0               0.000000
# Amt Rcvd From Custom    40.073205
# Amt Rcvd From Ins Co    40.073205
# Area / Locality          4.852594
# CGST(14%)               40.073205
# CGST(2.5%)              40.073205
# CGST(6%)                40.073205
# CGST(9%)                40.073205
# CITY                     0.000203
# Cash /Cashless Type     94.430384
# Claim No.               99.024200
# Cust Type                0.000000
# Customer No.             0.000000
# District                 0.000000
# Expiry Date             95.484386
# Gate Pass Date          91.689247
# Gate Pass Time           0.000000
# IGST(12%)               40.073205
# IGST(18%)               40.073205
# IGST(28%)               40.073205
# IGST(5%)                40.073205
# Insurance Company       95.208140
# Invoice Date             0.000000
# Invoice No               0.000000
# Invoice Time             0.000000
# Job Card No              0.000000
# JobCard Date             0.000000
# ...

# %%
invoice_df['Technician Name'].fillna(invoice_df['User ID'],inplace=True)

# %%
invoice_df[invoice_df['Technician Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Amt Rcvd From Custom, Amt Rcvd From Ins Co, Area / Locality, CGST(14%), CGST(2.5%), CGST(6%), CGST(9%), CITY, Cash /Cashless Type, Claim No., Cust Type, Customer No., District, Expiry Date, Gate Pass Date, Gate Pass Time, IGST(12%), IGST(18%), IGST(28%), IGST(5%), Insurance Company, Invoice Date, Invoice No, Invoice Time, Job Card No, JobCard Date, JobCard Time, KMs Reading, Labour Total, Make, Misc Total, Model, ODN No., OSL Total, Order Type, Outstanding Amt, Parts Total, Pin code, Plant, Plant Name1, Policy no., Print Status, Recovrbl Exp, Regn No, SGST/UGST(14%), SGST/UGST(2.5%), SGST/UGST(6%), SGST/UGST(9%), Service Advisor Name, TDS amount, Technician Name, Total Amt Wtd Tax., Total CGST, Total GST, Total IGST, Total SGST/UGST, Total Value, User ID]
# Index: []

# %%
invoice_df['Technician Name'].unique()
# Out:
# array(['RUPESH', 'PRASHANT', 'IMRAN', ..., 'X211SA1', 'X418WM1',
#        'X341WM1'], dtype=object)

# %%
invoice_df['Technician Name'].nunique()
# Out:
# 15570

# %%
invoice_df['Total Value']  = invoice_df.apply(
    lambda x:x['Total Amt Wtd Tax.'] if np.isnan(x['Total Value']) else x['Total Value'],
    axis=1
)

# %%
invoice_df.drop(columns=['Unnamed: 0','Amt Rcvd From Custom','Amt Rcvd From Ins Co','CGST(14%)','CGST(2.5%)','CGST(6%)',
                         'CGST(9%)','IGST(12%)','IGST(18%)','IGST(28%)','IGST(5%)','Outstanding Amt',
                        'SGST/UGST(14%)','SGST/UGST(2.5%)','SGST/UGST(6%)','SGST/UGST(9%)',
                         'TDS amount','Total CGST','Total GST','Total IGST','Total SGST/UGST',
                         'Service Advisor Name','Policy no.','ODN No.','Expiry Date','Gate Pass Date','Gate Pass Time',
                         'Cash /Cashless Type','Claim No.','Insurance Company','Print Status','Area / Locality','Plant Name1','User ID','Total Amt Wtd Tax.','Recovrbl Exp'],axis=1,inplace=True)

# %%
invoice_df.dropna(inplace=True)

# %%
invoice_df.isnull().sum()
# Out:
# CITY               0
# Cust Type          0
# Customer No.       0
# District           0
# Invoice Date       0
# Invoice No         0
# Invoice Time       0
# Job Card No        0
# JobCard Date       0
# JobCard Time       0
# KMs Reading        0
# Labour Total       0
# Make               0
# Misc Total         0
# Model              0
# OSL Total          0
# Order Type         0
# Parts Total        0
# Pin code           0
# Plant              0
# Regn No            0
# Technician Name    0
# Total Value        0
# dtype: int64

# %%
invoice_df['year'] = pd.to_datetime(invoice_df['Invoice Date']).dt.year
invoice_df['month'] = pd.to_datetime(invoice_df['Invoice Date']).dt.month

# %%
invoice_df['invoice_datetime'] = invoice_df['Invoice Date']+ ' ' +invoice_df['Invoice Time']
invoice_df['jobcard_datetime'] = invoice_df['JobCard Date']+ ' ' +invoice_df['JobCard Time']

# %%
invoice_df["InvoiceDateTime"]=pd.to_datetime(invoice_df["invoice_datetime"],dayfirst=True)
invoice_df["JobCardDateTime"]=pd.to_datetime(invoice_df["jobcard_datetime"],dayfirst=True)
invoice_df['Service_Time'] = invoice_df['InvoiceDateTime'] - invoice_df['JobCardDateTime']

# %%
invoice_df['Service_Time_Hrs'] = invoice_df['Service_Time']/np.timedelta64(1,'h')

# %%
invoice_df.head()
# Out:
#        CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0     Thane    Retail        67849  Maharashtra   2015-01-02  7005200002
# 1     THNAE    Retail        84419  Maharashtra   2015-01-03  7005200003
# 2  THANE[W]    Retail        81055  Maharashtra   2015-01-03  7005200004
# 3     THNAE    Retail        84419  Maharashtra   2015-01-03  7005200005
# 4     THANE    Retail        18980  Maharashtra   2015-01-03  7005200006
#
#   Invoice Time  Job Card No JobCard Date JobCard Time  KMs Reading  \
# 0     11:30:36       168303   2014-12-13     14:29:43        49317
# 1     10:07:32       173997   2015-01-02     14:12:18        78584
# 2     11:12:57       173889   2015-01-02     11:40:44        33985
# 3     11:40:44       174158   2015-01-03     10:12:32        78584
# 4     12:07:17       173860   2015-01-02     10:45:42        50057
#
#    Labour Total            Make  Misc Total        Model  OSL Total  \
# ...

# %%
invoice_df.drop(columns=['JobCard Date','invoice_datetime','jobcard_datetime','InvoiceDateTime','JobCardDateTime','Service_Time','Invoice Time','JobCard Time'],axis=1,inplace=True)

# %%
invoice_df.head()
# Out:
#        CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0     Thane    Retail        67849  Maharashtra   2015-01-02  7005200002
# 1     THNAE    Retail        84419  Maharashtra   2015-01-03  7005200003
# 2  THANE[W]    Retail        81055  Maharashtra   2015-01-03  7005200004
# 3     THNAE    Retail        84419  Maharashtra   2015-01-03  7005200005
# 4     THANE    Retail        18980  Maharashtra   2015-01-03  7005200006
#
#    Job Card No  KMs Reading  Labour Total            Make  Misc Total  \
# 0       168303        49317   1203.140000  GENERAL MOTORS    0.000000
# 1       173997        78584    804.260000     TATA MOTORS  197.030000
# 2       173889        33985    180.190000   MARUTI SUZUKI    0.000000
# 3       174158        78584      0.000000     TATA MOTORS    0.000000
# 4       173860        50057   1202.970000         HYUNDAI  100.000000
#
#          Model  OSL Total         Order Type  Parts Total  Pin code Plant  \
# ...

# %%
invoice_df['CITY'] = invoice_df['CITY'].str.lower()
invoice_df['CITY'] = invoice_df['CITY'].map(lambda x: 'nashik' if x=='nasik' else x)
invoice_df['CITY'] = invoice_df['CITY'].map(lambda x: 'thane' if x=='thane(w)' else x)
invoice_df['CITY'] = invoice_df['CITY'].map(lambda x: 'thane' if x=='thane[w]' else x)

# %%
invoice_df.head()
# Out:
#     CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0  thane    Retail        67849  Maharashtra   2015-01-02  7005200002
# 1  thnae    Retail        84419  Maharashtra   2015-01-03  7005200003
# 2  thane    Retail        81055  Maharashtra   2015-01-03  7005200004
# 3  thnae    Retail        84419  Maharashtra   2015-01-03  7005200005
# 4  thane    Retail        18980  Maharashtra   2015-01-03  7005200006
#
#    Job Card No  KMs Reading  Labour Total            Make  Misc Total  \
# 0       168303        49317   1203.140000  GENERAL MOTORS    0.000000
# 1       173997        78584    804.260000     TATA MOTORS  197.030000
# 2       173889        33985    180.190000   MARUTI SUZUKI    0.000000
# 3       174158        78584      0.000000     TATA MOTORS    0.000000
# 4       173860        50057   1202.970000         HYUNDAI  100.000000
#
#          Model  OSL Total         Order Type  Parts Total  Pin code Plant  \
# ...

# %%
invoice_df.shape
# Out:
# (490773, 23)

# %%
invoice_df['Customer No.'].nunique() # 253484
# Out:
# 252845

# %%
invoice_df['Customer No.'] = invoice_df['Customer No.'].str.lstrip('0')
customer_df['Customer No.'] = customer_df['Customer No.'].astype(str)

# %%
#merge customer and invoice
invoice_customer_df =  pd.merge(invoice_df, customer_df,on='Customer No.') # invoice_df.join(custmer_df.set_index('Customer No.'), on='Customer No.')

# %%
invoice_customer_df.shape
# Out:
# (367694, 26)

# %%
invoice_customer_df.isnull().sum()
# Out:
# CITY                0
# Cust Type           0
# Customer No.        0
# District            0
# Invoice Date        0
# Invoice No          0
# Job Card No         0
# KMs Reading         0
# Labour Total        0
# Make                0
# Misc Total          0
# Model               0
# OSL Total           0
# Order Type          0
# Parts Total         0
# Pin code            0
# Plant               0
# Regn No             0
# Technician Name     0
# Total Value         0
# year                0
# month               0
# Service_Time_Hrs    0
# Partner Type        0
# Data Origin         0
# Title               0
# dtype: int64

# %%
invoice_customer_df.head()
# Out:
#     CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0  thane    Retail        67849  Maharashtra   2015-01-02  7005200002
# 1  thane    Retail        67849  Maharashtra   2014-08-14  7000137359
# 2  thane    Retail        67849  Maharashtra   2014-08-16  7000137489
# 3  thane    Retail        67849  Maharashtra   2014-10-09  7000151113
# 4  thane    Retail        67849  Maharashtra   2014-12-31  7000175211
#
#    Job Card No  KMs Reading  Labour Total            Make  Misc Total  Model  \
# 0       168303        49317   1203.140000  GENERAL MOTORS    0.000000  SPARK
# 1       136482        45575    989.980000  GENERAL MOTORS    0.000000  SPARK
# 2       135895        45575   6473.050000  GENERAL MOTORS    0.000000  SPARK
# 3       150383        47556      0.000000  GENERAL MOTORS    0.000000  SPARK
# 4       168210        49317   1760.020000  GENERAL MOTORS  500.000000  SPARK
#
#     OSL Total       Order Type  Parts Total  Pin code Plant     Regn No  \
# ...

# %%
plant_df['Plant'] = plant_df['Plant'].astype(str)

# %%
#merge plant and invoice_customer
invoice_customer_plant_df =  pd.merge(invoice_customer_df, plant_df, on='Plant')

# %%
invoice_customer_plant_df.shape
# Out:
# (204840, 32)

# %%
invoice_customer_plant_df.head()
# Out:
#      CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0  nashik    Retail        54971  Maharashtra   2016-08-19  7169800818
# 1  nashik    Retail        54493  Maharashtra   2016-09-10  7169801078
# 2  nashik    Retail        73552  Maharashtra   2016-07-09  7169800547
# 3  nashik    Retail       E16200  Maharashtra   2016-08-03  7169800756
# 4  nashik    Retail        90858  Maharashtra   2016-07-21  7169800602
#
#    Job Card No  KMs Reading  Labour Total                  Make  Misc Total  \
# 0       436123          123    699.050000         MARUTI SUZUKI  660.060000
# 1       456143        64496   1048.940000  MAHINDRA &  MAHINDRA  798.950000
# 2       405557        64932    599.040000               HYUNDAI    0.000000
# 3       424352        58000     99.140000                TOYOTA    0.000000
# 4       400292       114771   3692.980000               HYUNDAI    0.000000
#
#      Model  OSL Total       Order Type  Parts Total  Pin code Plant  \
# ...

# %%
#merge plant and invoice_customer
final_df =  pd.merge(invoice_customer_plant_df, jtd_grouped, left_on='Job Card No', right_on='DBM Order')

# %%
final_df.shape
# Out:
# (196011, 37)

# %%
final_df.isnull().sum()
# Out:
# CITY                       0
# Cust Type                  0
# Customer No.               0
# District                   0
# Invoice Date               0
# Invoice No                 0
# Job Card No                0
# KMs Reading                0
# Labour Total               0
# Make                       0
# Misc Total                 0
# Model                      0
# OSL Total                  0
# Order Type                 0
# Parts Total                0
# Pin code                   0
# Plant                      0
# Regn No                    0
# Technician Name            0
# Total Value                0
# year                       0
# month                      0
# Service_Time_Hrs           0
# Partner Type               0
# Data Origin                0
# Title                      0
# Name 1                     0
# House number and street    0
# Postal Code                0
# City                       0
# Sales organization         0
# State                      0
# ...

# %%
final_df.head()
# Out:
#      CITY Cust Type Customer No.     District Invoice Date  Invoice No  \
# 0  nashik    Retail        54971  Maharashtra   2016-08-19  7169800818
# 1  nashik    Retail        54493  Maharashtra   2016-09-10  7169801078
# 2  nashik    Retail        73552  Maharashtra   2016-07-09  7169800547
# 3  nashik    Retail       E16200  Maharashtra   2016-08-03  7169800756
# 4  nashik    Retail        90858  Maharashtra   2016-07-21  7169800602
#
#    Job Card No  KMs Reading  Labour Total                  Make  Misc Total  \
# 0       436123          123    699.050000         MARUTI SUZUKI  660.060000
# 1       456143        64496   1048.940000  MAHINDRA &  MAHINDRA  798.950000
# 2       405557        64932    599.040000               HYUNDAI    0.000000
# 3       424352        58000     99.140000                TOYOTA    0.000000
# 4       400292       114771   3692.980000               HYUNDAI    0.000000
#
#      Model  OSL Total       Order Type  Parts Total  Pin code Plant  \
# ...

# %%
final_df.to_csv('data/merged_data.csv',index=False)
